# %%
import os, sys
import numpy as np
import datetime
import warnings
import re
import pandas as pd
from EEG_feature_extraction import generate_feature_vectors_from_samples

# %%
# Gets rid of pesky warnings about the logm not bein accurate, could be worth going back and looking at these later
warnings.filterwarnings(
    "ignore",
    message="logm result may be inaccurate*",
    category=RuntimeWarning
)

# %%
# Generate the feature extraction for the NeuroSense data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			_,name,_,_,_,state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'happy':
			state = 3.
		elif state.lower() == 'relaxed':
			state = 2.
		elif state.lower() == 'sad':
			state = 1.
		elif state.lower() == 'angry':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)

		# jerry rig some new columns to add on to the featureset	
		valence_arousal = pd.read_csv(full_file_path)[["Valence", "Arousal"]].to_numpy()[:vectors.shape[0]]
		# print(valence_arousal)
		vectors = np.hstack([vectors, valence_arousal])
		header = np.hstack([header, "Valence", "Arousal"])

		print('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack([FINAL_MATRIX, vectors])

	print('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "NeuroSense" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = [5, 6])
# Out:
# Using file sub-ID030-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID011-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID014-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID023-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID008-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID030-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID024-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID009-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (62, 992)
# Using file sub-ID018-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (134, 992)
# Using file sub-ID027-ses-S031-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID022-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID008-ses-S014-mellow-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID030-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID029-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (42, 992)
# Using file sub-ID029-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID022-ses-S021-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID019-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID021-ses-S021-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID018-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID003-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID012-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID029-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID028-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID010-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID008-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID001-ses-S031-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID027-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID012-ses-S003-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID005-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID020-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID029-ses-S031-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID019-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID007-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID007-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID029-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID024-ses-S034-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID029-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID009-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID019-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID009-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID024-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID010-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID025-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID010-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID009-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID001-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID019-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID009-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID010-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID029-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID013-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID008-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID023-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID001-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID029-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID001-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID009-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID024-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID005-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID025-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID025-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID023-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID005-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID026-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID023-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID016-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID019-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID017-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID013-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID007-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID011-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID016-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID012-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (134, 992)
# Using file sub-ID019-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID028-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID026-ses-S014-mellow-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID019-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID022-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID016-ses-S040-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID025-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID017-ses-S040-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID017-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID026-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID019-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID027-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID010-ses-S001-fun-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID028-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID015-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID029-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID024-ses-S001-fun-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID014-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID028-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID000-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID005-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (134, 992)
# Using file sub-ID006-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID021-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID002-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID008-ses-S021-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID007-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID025-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID017-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID027-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID025-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID018-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (138, 992)
# Using file sub-ID009-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID026-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID025-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID020-ses-S031-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID025-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID014-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID014-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID028-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID005-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID012-ses-S014-mellow-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID008-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID027-ses-S014-mellow-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID028-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID020-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID013-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID013-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID003-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID002-ses-S031-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID012-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID008-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID017-ses-S014-mellow-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID000-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID026-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID007-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID030-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID019-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID018-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (140, 992)
# Using file sub-ID002-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID012-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID014-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID005-ses-S001-fun-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID021-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID006-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID026-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID015-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID025-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID022-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID005-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID028-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID019-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID020-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID023-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID000-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID013-ses-S003-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID013-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID001-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID007-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (72, 992)
# Using file sub-ID023-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID009-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (134, 992)
# Using file sub-ID000-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID013-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID029-ses-S021-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (136, 992)
# Using file sub-ID005-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID001-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID029-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID028-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID014-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID025-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID000-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S001-fun-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID006-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID005-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID018-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID009-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID022-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID021-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID027-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID010-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID028-ses-S021-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID000-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID013-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID011-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID011-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID012-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID025-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID014-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID023-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID017-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID005-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID003-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID020-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID002-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID000-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID026-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID024-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID028-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID003-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID020-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID026-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID015-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID023-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID011-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID028-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID019-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID017-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID018-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (136, 992)
# Using file sub-ID029-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID017-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID018-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (136, 992)
# Using file sub-ID005-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID029-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID002-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID000-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID019-ses-S021-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID001-ses-S003-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID008-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID009-ses-S034-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID009-ses-S040-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID011-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID029-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID019-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID015-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (140, 992)
# Using file sub-ID027-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID015-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID015-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID005-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID030-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID022-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID027-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID003-ses-S007-happy-Relaxed-cleaned.csv
# logm result may be inaccurate, approximate err = 3.579073101500607e-13
# /yunity/msn39/EEG_Social_Media_Insights/code/EEG_feature_extraction.py:265: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skw = scipy.stats.skew(matrix, axis = 0, bias = False)
# /yunity/msn39/EEG_Social_Media_Insights/code/EEG_feature_extraction.py:266: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   krt = scipy.stats.kurtosis(matrix, axis = 0, bias = False)
# /yunity/msn39/miniconda3/envs/autoencoders/lib/python3.12/site-packages/scipy/linalg/_matfuncs.py:200: LogmExactlySingularWarning: The logm input matrix is exactly singular.
#   F = scipy.linalg._matfuncs_inv_ssq._logm(A)
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID012-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID002-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID014-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID008-ses-S034-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID001-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID020-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID002-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID000-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID012-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID003-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID003-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID010-ses-S012-sad-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (120, 992)
# Using file sub-ID011-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID000-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID009-ses-S014-mellow-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID018-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (136, 992)
# Using file sub-ID000-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID018-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (136, 992)
# Using file sub-ID019-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID007-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID010-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID002-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID021-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID021-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID015-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (118, 992)
# Using file sub-ID014-ses-S001-fun-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID005-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID011-ses-S001-fun-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (24, 992)
# Using file sub-ID028-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID029-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID024-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID015-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID014-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID013-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID030-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID029-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID011-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID028-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID002-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID015-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID022-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID014-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (72, 992)
# Using file sub-ID002-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID011-ses-S040-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID006-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID030-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID019-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID029-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID022-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID009-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID000-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID005-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID010-ses-S040-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID012-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID003-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID000-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID015-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID027-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID012-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID002-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID026-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID026-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID002-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID001-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID012-ses-S020-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID001-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID000-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID019-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID024-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID012-ses-S037-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID017-ses-S038-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID022-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID022-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID016-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID028-ses-S003-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID027-ses-S040-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID029-ses-S039-nan-Happy-cleaned.csv
# /yunity/msn39/miniconda3/envs/autoencoders/lib/python3.12/site-packages/scipy/linalg/_matfuncs.py:200: LogmNearlySingularWarning: The logm input matrix may be nearly singular.
#   F = scipy.linalg._matfuncs_inv_ssq._logm(A)
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID009-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID002-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID001-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID013-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (118, 992)
# Using file sub-ID008-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID018-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (136, 992)
# Using file sub-ID024-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID021-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID014-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID020-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID019-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID019-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID030-ses-S021-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID020-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID011-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID013-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (134, 992)
# Using file sub-ID002-ses-S001-fun-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID029-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID012-ses-S015-terrible-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID010-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID021-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID022-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID023-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID003-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID024-ses-S016-shock-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (160, 992)
# Using file sub-ID019-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID027-ses-S007-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID005-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID018-ses-S033-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID003-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID010-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID002-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID006-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID003-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID028-ses-S030-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID017-ses-S035-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID016-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID011-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID027-ses-S027-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID016-ses-S014-mellow-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID023-ses-S028-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID007-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (68, 992)
# Using file sub-ID022-ses-S013-depressing-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID030-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID016-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID018-ses-S024-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (134, 992)
# Using file sub-ID015-ses-S034-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (122, 992)
# Using file sub-ID017-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (118, 992)
# Using file sub-ID024-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID027-ses-S034-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID002-ses-S006-love-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID011-ses-S023-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID021-ses-S003-happy-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID030-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID017-ses-S011-sentimental-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID009-ses-S029-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID027-ses-S026-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID026-ses-S008-lovely-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID025-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID006-ses-S017-hate-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (134, 992)
# Using file sub-ID010-ses-S031-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID008-ses-S025-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID019-ses-S009-sentimental-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (132, 992)
# Using file sub-ID000-ses-S040-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (80, 992)
# Using file sub-ID017-ses-S039-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID023-ses-S002-exciting-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID025-ses-S005-cheerful-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID014-ses-S004-joy-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID012-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID025-ses-S018-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID003-ses-S032-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID003-ses-S036-nan-Angry-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID029-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (126, 992)
# Using file sub-ID010-ses-S010-melancholy-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID028-ses-S031-nan-Sad-cleaned.csv
# End of recording break
# resulting vector shape for the file (128, 992)
# Using file sub-ID002-ses-S022-nan-Relaxed-cleaned.csv
# End of recording break
# resulting vector shape for the file (124, 992)
# Using file sub-ID021-ses-S019-nan-Happy-cleaned.csv
# End of recording break
# resulting vector shape for the file (130, 992)
# Using file sub-ID014-ses-S027-nan-Happy-cleaned.csv

# %%
#This is the generating matrix code for the original github data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'concentrating':
			state = 2.
		elif state.lower() == 'neutral':
			state = 1.
		elif state.lower() == 'relaxed':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "original_data" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = -1)
# Out:
# Using file name-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (102, 990)
# Using file subjecta-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (117, 990)
# Using file subjecta-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjecta-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectb-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (86, 990)
# Using file subjectb-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (87, 990)
# Using file subjectb-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (117, 990)
# Using file subjectb-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectb-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectb-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (6, 990)
# Using file subjectc-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (16, 990)
# Using file subjectc-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectc-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (117, 990)
# Using file subjectd-concentrating-1.csv
# Slice too short break
# resulting vector shape for the file (86, 990)
# Using file subjectd-concentrating-2.csv
# Slice too short break
# resulting vector shape for the file (5, 990)
# Using file subjectd-neutral-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectd-neutral-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectd-relaxed-1.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# Using file subjectd-relaxed-2.csv
# Slice too short break
# resulting vector shape for the file (116, 990)
# FINAL_MATRIX (2479, 990)

# %%
# This is the generating matrix code for Mendeley Data

def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, _ ,state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == '1':
			state = 1.
		elif state.lower() == '2':
			state = 2.
		elif state.lower() == '3':
			state = 3.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "Mendeley cleaned" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = [1,2,3,4])
# Out:
# Using file subject1-label-1-cleaned.csv
# Slice too short break
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (357, 1247)
# Using file subject1-label-2-cleaned.csv
# End of recording break
# resulting vector shape for the file (363, 1247)
# Using file subject1-label-3-cleaned.csv
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (363, 1247)
# Using file subject2-label-1-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Index break
# Slice too short break
# Index break
# Index break
# End of recording break
# resulting vector shape for the file (327, 1247)
# Using file subject2-label-2-cleaned.csv
# Slice too short break
# End of recording break
# resulting vector shape for the file (360, 1247)
# Using file subject2-label-3-cleaned.csv
# Slice too short break
# End of recording break
# resulting vector shape for the file (363, 1247)
# Using file subject3-label-1-cleaned.csv
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (359, 1247)
# Using file subject3-label-2-cleaned.csv
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (322, 1247)
# Using file subject3-label-3-cleaned.csv
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (328, 1247)
# Using file subject4-label-1-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (234, 1247)
# Using file subject4-label-2-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (290, 1247)
# Using file subject4-label-3-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (299, 1247)
# Using file subject5-label-1-cleaned.csv
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (388, 1247)
# Using file subject5-label-2-cleaned.csv
# Slice too short break
# End of recording break
# resulting vector shape for the file (363, 1247)
# Using file subject5-label-3-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (343, 1247)
# FINAL_MATRIX (5059, 1247)

# %%
#This is the generating matrix code for our own data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, state, _, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == 'Marshall':
			state = 2.
		elif state.lower() == 'label':
			state = 1.
		elif state.lower() == 'Kenzo':
			state = 0.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "local datasets" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = [5,6,7,8,9])
# Out:
# Using file subjectNatalie-label-1-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (67, 990)
# FINAL_MATRIX (67, 990)

# %%
# This is the generating matrix code for the Emotion data
def gen_training_matrix(directory_path, output_file, cols_to_ignore):
	# Initialise return matrix
	FINAL_MATRIX = None
	
	for x in os.listdir(directory_path):

		# Ignore non-CSV files
		if not x.lower().endswith('.csv'):
			continue
		
		# For safety we'll ignore files containing the substring "test". 
		# [Test files should not be in the dataset directory in the first place]
		if 'test' in x.lower():
			continue
		try:
			name, _ ,state, _ = x[:-4].split('-')
		except:
			print ('Wrong file name', x)
			sys.exit(-1)
		if state.lower() == '1': #Anger
			state = 1.
		elif state.lower() == '2': #Fear
			state = 2.
		elif state.lower() == '3': #Happiness
			state = 3.
		elif state.lower() == '4': #Sadness
			state = 4.
		else:
			print ('Wrong file name', x)
			sys.exit(-1)
			
		print ('Using file', x)
		full_file_path = directory_path  +   '/'   + x
		vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path, 
														        nsamples = 150, 
																period = 1.,
																state = state,
														        remove_redundant = True,
																cols_to_ignore = cols_to_ignore)
		
		print ('resulting vector shape for the file', vectors.shape)
		
		
		if FINAL_MATRIX is None:
			FINAL_MATRIX = vectors
		else:
			FINAL_MATRIX = np.vstack( [ FINAL_MATRIX, vectors ] )

	print ('FINAL_MATRIX', FINAL_MATRIX.shape)
	
	# Shuffle rows
	# np.random.shuffle(FINAL_MATRIX)
	
	# Save to file
	np.savetxt(output_file, FINAL_MATRIX, delimiter = ',',
			header = ','.join(header), 
			comments = '')

	return None


if __name__ == '__main__':
	
	
	# if len(sys.argv) < 3: # For use in calling the function from the command line
	# 	print ('arg1: input dir\narg2: output file')
	# 	sys.exit(-1)

	date = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M')

	target_dir = "Emotion cleaned" # Change this one to change which data we're processing
	directory_path = "../cleaned datasets/" + target_dir

	output_file = f"../featuresets/{target_dir}_{date}.csv"
    
	gen_training_matrix(directory_path, output_file, cols_to_ignore = [1,2,3,4])
# Out:
# Using file subject1-label-1-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (66, 1247)
# Using file subject1-label-2-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (140, 1247)
# Using file subject1-label-3-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (55, 1247)
# Using file subject1-label-4-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (74, 1247)
# Using file subject10-label-1-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (74, 1247)
# Using file subject10-label-2-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (150, 1247)
# Using file subject10-label-3-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (74, 1247)
# Using file subject10-label-4-cleaned.csv
# End of recording break
# resulting vector shape for the file (18, 1247)
# Using file subject11-label-1-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (76, 1247)
# Using file subject11-label-2-cleaned.csv
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# End of recording break
# resulting vector shape for the file (139, 1247)
# Using file subject11-label-3-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# End of recording break
# resulting vector shape for the file (49, 1247)
# Using file subject11-label-4-cleaned.csv
# End of recording break
# resulting vector shape for the file (18, 1247)
# Using file subject12-label-1-cleaned.csv
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Slice too short break
# Slice too short break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# Index break
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 77
#      73 directory_path = "../cleaned datasets/" + target_dir
#      75 output_file = f"../featuresets/{target_dir}_{date}.csv"
# ---> 77 gen_training_matrix(directory_path, output_file, cols_to_ignore = [1,2,3,4])
#
# Cell In[6], line 35, in gen_training_matrix(directory_path, output_file, cols_to_ignore)
#      33 print ('Using file', x)
#      34 full_file_path = directory_path  +   '/'   + x
# ---> 35 vectors, header = generate_feature_vectors_from_samples(file_path = full_file_path,
#      36 												        nsamples = 150,
#      37 														period = 1.,
#      38 														state = state,
#      39 												        remove_redundant = True,
#      40 														cols_to_ignore = cols_to_ignore)
#      42 print ('resulting vector shape for the file', vectors.shape)
#      45 if FINAL_MATRIX is None:
#
# File c:\Users\Administrator\Documents\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:894, in generate_feature_vectors_from_samples(file_path, nsamples, period, state, remove_redundant, cols_to_ignore)
#     887 t += 0.5 * period
#     890 # Compute the feature vector. We will be appending the features of the
#     891 # current time slice and those of the previous one.
#     892 # If there was no previous vector we just set it and continue
#     893 # with the next vector.
# --> 894 r, headers = calc_feature_vector(ry, state)
#     896 if previous_vector is not None:
#     897 	# If there is a previous vector, the script concatenates the two
#     898 	# vectors with the timestamp and adds the result to the output matrix
#     899 	feature_vector = np.hstack([[t], previous_vector, r])
#
# File c:\Users\Administrator\Documents\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:756, in calc_feature_vector(matrix, state)
#     753 var_names += v
#     754 var_values = np.hstack([var_values, x])
# --> 756 x, v, log_cov = feature_logcov(covM)
#     757 var_names += v
#     758 var_values = np.hstack([var_values, x])
#
# File c:\Users\Administrator\Documents\EEG_Social_Media_Analysis\code\EEG_feature_extraction.py:576, in feature_logcov(covM)
#     537 def feature_logcov(covM):
#     538 	"""
#     539 	Computes the matrix logarithm of the covariance matrix of the signals.
#     540 	Since the matrix is symmetric, only the lower triangular elements
#    (...)    574 		Original: [fcampelo]
#     575 	"""
# --> 576 	log_cov = scipy.linalg.logm(covM)
#     577 	indx = np.triu_indices(log_cov.shape[0])
#     578 	ret  = np.abs(log_cov[indx])
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\_lib\_util.py:1226, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1224 # Early exit if call is not batched
#    1225 if not any(batch_shapes):
# -> 1226     return f(*arrays, *other_args, **kwargs)
#    1228 # Determine broadcasted batch shape
#    1229 batch_shape = np.broadcast_shapes(*batch_shapes)  # Gives OK error message
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\linalg\_matfuncs.py:218, in logm(A, disp)
#     216 # Avoid circular import ... this is OK, right?
#     217 import scipy.linalg._matfuncs_inv_ssq
# --> 218 F = scipy.linalg._matfuncs_inv_ssq._logm(A)
#     219 F = _maybe_real(A, F)
#     220 errtol = 1000*eps
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\linalg\_matfuncs_inv_ssq.py:880, in _logm(A)
#     878     T, Z = schur(A, output='complex')
#     879 T = _logm_force_nonsingular_triangular_matrix(T, inplace=True)
# --> 880 U = _logm_triu(T)
#     881 ZH = np.conjugate(Z).T
#     882 return Z.dot(U).dot(ZH)
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\linalg\_matfuncs_inv_ssq.py:777, in _logm_triu(T)
#     770 # Define bounds given in Table (2.1).
#     771 theta = (None,
#     772         1.59e-5, 2.31e-3, 1.94e-2, 6.21e-2,
#     773         1.28e-1, 2.06e-1, 2.88e-1, 3.67e-1,
#     774         4.39e-1, 5.03e-1, 5.60e-1, 6.09e-1,
#     775         6.52e-1, 6.89e-1, 7.21e-1, 7.49e-1)
# --> 777 R, s, m = _inverse_squaring_helper(T0, theta)
#     779 # Evaluate U = 2**s r_m(T - I) using the partial fraction expansion (1.1).
#     780 # This requires the nodes and weights
#     781 # corresponding to degree-m Gauss-Legendre quadrature.
#     782 # These quadrature arrays need to be transformed from the [-1, 1] interval
#     783 # to the [0, 1] interval.
#     784 nodes, weights = scipy.special.p_roots(m)
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\linalg\_matfuncs_inv_ssq.py:395, in _inverse_squaring_helper(T0, theta)
#     393 if s > s0:
#     394     d3 = _onenormest_m1_power(T, 3) ** (1/3)
# --> 395 d4 = _onenormest_m1_power(T, 4) ** (1/4)
#     396 a3 = max(d3, d4)
#     397 if a3 <= theta[7]:
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\linalg\_matfuncs_inv_ssq.py:111, in _onenormest_m1_power(A, p, t, itmax, compute_v, compute_w)
#      74 def _onenormest_m1_power(A, p,
#      75         t=2, itmax=5, compute_v=False, compute_w=False):
#      76     """
#      77     Efficiently estimate the 1-norm of (A - I)^p.
#      78
#    (...)    109
#     110     """
# --> 111     return onenormest(_MatrixM1PowerOperator(A, p),
#     112             t=t, itmax=itmax, compute_v=compute_v, compute_w=compute_w)
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\sparse\linalg\_onenormest.py:107, in onenormest(A, t, itmax, compute_v, compute_w)
#     105     est = col_abs_sums[argmax_j]
#     106 else:
# --> 107     est, v, w, nmults, nresamples = _onenormest_core(A, A.H, t, itmax)
#     109 # Report the norm estimate along with some certificates of the estimate.
#     110 if compute_v or compute_w:
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\sparse\linalg\_onenormest.py:436, in _onenormest_core(A, AT, t, itmax)
#     434 del S_old
#     435 # (3)
# --> 436 Z = np.asarray(AT_linear_operator.matmat(S))
#     437 nmults += 1
#     438 h = _max_abs_axis1(Z)
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\sparse\linalg\_interface.py:366, in LinearOperator.matmat(self, X)
#     363     raise ValueError(f'dimension mismatch: {self.shape}, {X.shape}')
#     365 try:
# --> 366     Y = self._matmat(X)
#     367 except Exception as e:
#     368     if issparse(X) or is_pydata_spmatrix(X):
#
# File c:\Users\Administrator\anaconda3\envs\neuromodulation\Lib\site-packages\scipy\linalg\_matfuncs_inv_ssq.py:66, in _MatrixM1PowerOperator._matmat(self, X)
#      64 def _matmat(self, X):
#      65     for i in range(self._p):
# ---> 66         X = self._A.dot(X) - X
#      67     return X
#
# KeyboardInterrupt:
